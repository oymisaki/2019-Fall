# %%
[1, 2] == [0, 2]
# Out:
# False

# %%
np.array([1, 2]) + [0, 2]
# Out:
# array([1, 4])

# %%
- np.array([1, 2])
# Out:
# array([-1, -2])

# %%
np.array([1, 2]) == np.array([1, 2])
# Out:
# array([ True,  True])

# %%
np.array([1, 2]) * np.array([1, 2])
# Out:
# array([1, 4])

# %%
np.matrix([1, 1]) * np.matrix([1, 2]).reshape((2, 1))
# Out:
# matrix([[3]])

# %%
np.zeros(np.matrix([1, 1]).T.shape)
# Out:
# array([[0.],
#        [0.]])

# %%
np.identity(2)
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
import numpy as np
import math

# %%
def Jacobian(x : list):
    return [[x[1] ** 3 - 7, 3 * (x[0] + 3) * (x[1] ** 2)], 
            [math.cos(x[1] * math.exp(x[0]) - 1) * x[1] * math.exp(x[0]), 
            math.cos(x[1] * math.exp(x[0]) - 1) * math.exp(x[0])]]
    
Jacobian([-0.5, 1.4])
# Out:
# [[-4.256, 14.699999999999998], [0.83949889738304, 0.5996420695593143]]

# %%
def NewtonMethod():
    def Jacobian(x : list):
        return [[x[1] ** 3 - 7, 3 * (x[0] + 3) * (x[1] ** 2)], 
                [math.cos(x[1] * math.exp(x[0]) - 1) * x[1] * math.exp(x[0]), 
                math.cos(x[1] * math.exp(x[0]) - 1) * math.exp(x[0])]]
    
    def f(x : list):
        return np.array([(x[0] + 3) * (x[1] ** 3  - 7) + 18, math.sin(x[1] * math.exp(x[0]) - 1)])
    
    
    x1 = np.array([-0.5, 1.4])
    x0 = np.array([0, 0])
    while(not (x1 == x0).all()):
        x0 = x1
        sol = np.linalg.solve(Jacobian(x0), -f(x0))
        x1 = x0 + sol
        print("Error: ", x1 - [0, 1])
    

NewtonMethod()
# Out:
# Error:  [-0.05531514  0.02806658]
# Error:  [-0.00014035  0.0001574 ]
# Error:  [-1.77907770e-08  5.55138535e-09]
# Error:  [1.18056312e-16 0.00000000e+00]
# Error:  [-1.51704507e-17 -1.11022302e-16]
# Error:  [ 5.14429307e-17 -1.11022302e-16]
# Error:  [ 1.18056312e-16 -1.11022302e-16]
# Error:  [ 1.18056312e-16 -1.11022302e-16]

# %%
def BroydenMethod(): 
    def f(x : list):
        return np.array([(x[0] + 3) * (x[1] ** 3  - 7) + 18, math.sin(x[1] * math.exp(x[0]) - 1)])
    
    B0 = np.matrix([[-4.256, 14.699999999999998], [0.83949889738304, 0.5996420695593143]])
    x1 = np.array([-0.5, 1.4])
    x0 = np.array([0, 0])
    while(not (x1 == x0).all()):
        x0 = x1
        sol = np.linalg.solve(B0, -f(x0))
        x1 = x0 + sol
        yk = np.matrix(f(x1) -  f(x0)).reshape((2, 1))
        denominator = (yk - B0 * np.matrix(sol).reshape((2, 1))) * np.matrix(sol).reshape((1, 2))
        B0 = B0 + denominator/sum(sol * sol)
        print("Error: ", x1 - [0, 1])

BroydenMethod()
# Out:
# Error:  [-0.05531514  0.02806658]
# Error:  [0.00050995 0.00012364]
# Error:  [-2.33847864e-04  7.65608693e-05]
# Error:  [-4.08262210e-05  1.35978908e-05]
# Error:  [-1.32750896e-07  4.53383611e-08]
# Error:  [-5.39120623e-10  1.80663262e-10]
# Error:  [ 1.66791236e-12 -5.57109914e-13]
# Error:  [-1.08051128e-15  4.44089210e-16]
# Error:  [-5.52378292e-18  0.00000000e+00]
# Error:  [-5.52378292e-18  0.00000000e+00]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in true_divide

# %%
def NewtonMethod(x1):
    def Jacobian(x : list):
        return [[0, 0, 1, 1], 
                [x[2], x[3], x[0], x[1]],
                [2 * x[2] * x[0], 2 * x[3] * x[1], x[0] ** 2, x[1] ** 2],
                [3 * x[2] * x[0] ** 2, 3 * x[3] * x[1] ** 2 , x[0] ** 3, x[1] ** 3 ]]
    
    def f(x : list):
        return np.array([x[2] + x[3]- 2,
                        x[2] * x[0] + x[3] * x[1],
                        x[2] * (x[0] ** 2) + x[3] * (x[1] ** 2) - 2.0/3,
                        x[2] * (x[0] ** 3) + x[3] * (x[1] ** 3)])
    
    x0 = np.array([float('inf'), 0, 0, 0])
    inum = 0
    while(inum <= 50 and not (x1 == x0).all()):
        inum += 1
        x0 = x1
        sol = np.linalg.solve(Jacobian(x0), -f(x0))
        x1 = x0 + sol
    return x1

NewtonMethod([-2, 1, 3, -1])
# Out:
# array([-0.57735027,  0.57735027,  1.        ,  1.        ])

# %%
NewtonMethod([-5, -4, -5, -4])
# Out:
# array([-0.57735027,  0.57735027,  1.        ,  1.        ])

# %%
def f(x : list):
    return np.array([x[2] + x[3]- 2,
                    x[2] * x[0] + x[3] * x[1],
                    x[2] * (x[0] ** 2) + x[3] * (x[1] ** 2) - 2.0/3,
                    x[2] * (x[0] ** 3) + x[3] * (x[1] ** 3)])
solSet = set()
for x1 in range(-10, 10):
    for x2 in range(-10, 10):
        for w1 in range(-10, 10):
            for w2 in range(-10, 10):
                try:
                    sol = NewtonMethod([x1,x2,w1,w2])
                    if str(sol) not in solSet:
                        solSet.add(str(sol))
                        if max(np.abs(f(sol))) < 0.001:
                            print([x1,x2,w1,w2], ": ", sol, " ", f(sol))
                except:
                    pass

# %%
import numpy as np

def experiment(epsilon):
    M = [[1.0, 1.0+epsilon],
        [1.0-epsilon, 1.0]]
    
    b = [1.0+(1.0+epsilon)*epsilon, 1.0]
    
    db = [epsilon * epsilon, 0]
    cond = np.linalg.cond(M, p=1)
    sol = np.linalg.solve(M, b)
    
    print("Experimental Epsilon: ", epsilon ** 2)
    print("Condtion Number: ", cond)
    print("Error Bounds: ", cond * np.linalg.norm(db, ord=1) / np.linalg.norm(M, ord=1))
    print("Relative Error for Each Components: ", [sol[0] - 1, sol[1]/epsilon - 1 ])
    print("Relative Error 2 Norm: ", np.linalg.norm(sol-[1, epsilon], ord=1) / np.linalg.norm([1, epsilon], ord=1))
    print("Solution is: ", sol)

# %%
def inverse(A : np.matrix):
    A1 = A.T / (np.linalg.norm(A, ord = 1) * np.linalg.norm(A, ord = np.inf))
    A0 = np.zeros(A.shape)
    I = np.identity(A.shape[0])
    while (not (A1 == A0).all()):
        A0 = A1
        A1 = A0 + A0 * (I - A * A0)
        print("Iteration: ", A1)
    
    return A1


A = np.matrix([[1, 2], [3, 4]])
inverse(A)
# Out:
# Iteration:  [[0.0260771  0.09410431]
#  [0.06462585 0.12131519]]
# Iteration:  [[0.01641549 0.10719556]
#  [0.07836241 0.12775027]]
# Iteration:  [[-0.00889062  0.11918758]
#  [ 0.09682261  0.12071549]]
# Iteration:  [[-0.05911992  0.1414131 ]
#  [ 0.13222455  0.10506267]]
# Iteration:  [[-0.15581293  0.18418717]
#  [ 0.20036597  0.07491896]]
# Iteration:  [[-0.33498744  0.26344859]
#  [ 0.32663369  0.01906192]]
# Iteration:  [[-0.64280394  0.39961733]
#  [ 0.54355788 -0.07689881]]
# Iteration:  [[-1.0982363   0.60108689]
#  [ 0.86450981 -0.21887828]]
# Iteration:  [[-1.60189919  0.82389219]
#  [ 1.21945071 -0.37589344]]
# Iteration:  [[-1.92241215  0.96567747]
#  [ 1.44532236 -0.47581226]]
# Iteration:  [[-1.9970529   0.99869629]
#  [ 1.49792312 -0.49908125]]
# Iteration:  [[-1.99999575  0.99999812]
#  [ 1.499997   -0.49999867]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# ...
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Iteration:  [[-2.   1. ]
#  [ 1.5 -0.5]]
