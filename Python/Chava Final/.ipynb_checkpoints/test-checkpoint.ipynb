# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data/records.csv")

# %%
data["CIK"]
# Out:
# 0         77098
# 1        785161
# 2         31791
# 3         30819
# 4         30697
#          ...
# 9594     916540
# 9595    1341766
# 9596    1102432
# 9597     936468
# 9598    1600626
# Name: CIK, Length: 9599, dtype: int64

# %%
CIK_CUSIP = pd.read_csv("data/cik-cusip_mapping_1993-2018.csv")
CIK_CUSIP.index = pd.MultiIndex.from_frame(CIK_CUSIP[["cik", "fyear"]])
CIK_CUSIP["cik"]
# Out:
# cik      fyear
# 20       1993          20
#          1994          20
#          1995          20
#          1996          20
#          1997          20
#                    ...
# 1739520  2015     1739520
#          2016     1739520
#          2017     1739520
#          2018     1739520
#          2019     1739520
# Name: cik, Length: 2042091, dtype: int64

# %%
len(set(data["CIK"]).difference(set(data["CIK"]).intersection(CIK_CUSIP["cik"])))
# Out:
# 1312

# %%
print(65771 in CIK_CUSIP["cik"])
d = CIK_CUSIP[["cusip"]].to_dict()
# Out:
# True

# %%
(65771, 1995) in d["cusip"]
# Out:
# True

# %%
data.columns
len(data)
# Out:
# 9599

# %%
cik = [d["cusip"][x]  if x in d["cusip"] else np.nan for x in zip(data["CIK"], [int(x[:4]) for x in data["date"]])]

# %%
data["CUSIP"] = pd.Series(cik, index=data.index)

# %%
data
# Out:
#           CIK        date     CUSIP
# 0       77098  1995-03-03  02909210
# 1      785161  1995-02-01  42192410
# 2       31791  1995-02-09  26845710
# 3       30819  1995-03-30  12650110
# 4       30697  1995-01-18  89592710
# ...       ...         ...       ...
# 9594   916540  2018-11-06  23726610
# 9595  1341766  2018-11-08  15118V20
# 9596  1102432  2018-11-20  92679510
# 9597   936468  2018-10-23  53983010
# 9598  1600626  2018-12-20       NaN
#
# [9599 rows x 3 columns]

# %%
data.to_csv("data/records.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-84135172e484> in <module>
# ----> 1 data.to_csv("data/records.csv", index=False)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3227             decimal=decimal,
#    3228         )
# -> 3229         formatter.save()
#    3230
#    3231         if path_or_buf is None:
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/formats/csvs.py in save(self)
#     200                 self.writer = UnicodeWriter(f, **writer_kwargs)
#     201
# --> 202             self._save()
#     203
#     204         finally:
#
# ...

# %%
data = pd.read_csv("data/sub_dsf.csv")

# %%
data.head()
data.replace('[a-Z]+',np.NaN,inplace=True)

# %%
data.to_pickle("data/sub_dsf.pkl")

# %%
data = pd.read_pickle("data/sub_dsf.pkl")

# %%
data.head()
# Out:
#       CUSIP        DATE      VOL       RET
# 0  12709510  01/14/1986      NaN       NaN
# 1  12709510  01/16/1986      NaN       NaN
# 2  12709510  01/17/1986   6000.0       NaN
# 3  12709510  01/20/1986  33700.0  0.029412
# 4  12709510  01/21/1986  20800.0  0.057143

# %%
ret_data = data.set_index(["CUSIP", "DATE"])['RET'].unstack(fill_value=0)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-8-9105c2aa28e0> in <module>
# ----> 1 ret_data = data.set_index(["CUSIP", "DATE"])['RET'].unstack(fill_value=0)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4394             frame = self
#    4395         else:
# -> 4396             frame = self.copy()
#    4397
#    4398         arrays = []
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in copy(self, deep)
#    5995         dtype: object
#    5996         """
# -> 5997         data = self._data.copy(deep=deep)
#    5998         return self._constructor(data).__finalize__(self)
#    5999
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in copy(self, deep)
#     785         else:
#     786             new_axes = list(self.axes)
# ...

# %%
ret_data.head()
# Out:
# DATE    01/02/1970 01/02/1973 01/02/1974 01/02/1975 01/02/1976 01/02/1979  \
# CUSIP
# 95710    -0.006897   0.000000   0.000000   0.125000   0.000000   0.000000
# 105510           0          0   0.000000   0.153846   0.000000  -0.075949
# 282410   -0.009804   0.008929   0.025063  -0.004926  -0.021212  -0.003704
# 780010    0.013605   0.013699   0.000000   0.082353   0.000000   0.000000
# 1165910   0.094118   0.000000   0.025641   0.142857   0.054054   0.051282
#
# DATE    01/02/1980 01/02/1981 01/02/1985 01/02/1986  ... 12/31/2004  \
# CUSIP                                                ...
# 95710     0.000000   0.000000  -0.010363  -0.015000  ...  -0.003033
# 105510   -0.057471   0.066667   0.005376   0.013575  ...  -0.004000
# 282410   -0.051672   0.006637  -0.026946  -0.005484  ...  -0.005754
# 780010   -0.041176   0.026667  -0.014599   0.019892  ...   0.000539
# 1165910   0.000000  -0.030303  -0.016529   0.000000  ...   0.009039
#
# ...

# %%
ret_data = data[["CUSIP", "DATE", "RET"]].pivot(index="DATE", columns = "CUSIP", values="RET")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-5-01a4dcbfa4cc> in <module>
# ----> 1 ret_data = data[["CUSIP", "DATE", "RET"]].pivot(index="DATE", columns = "CUSIP", values="RET")
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    5910         from pandas.core.reshape.pivot import pivot
#    5911
# -> 5912         return pivot(self, index=index, columns=columns, values=values)
#    5913
#    5914     _shared_docs[
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     428         else:
#     429             indexed = data._constructor_sliced(data[values].values, index=index)
# --> 430     return indexed.unstack(columns)
#     431
#     432
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in unstack(self, level, fill_value)
# ...

# %%
ret_data.astype("float64", copy=False)
ret_data.index = pd.to_datetime(ret_data.index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-ca4a39d62f98> in <module>
# ----> 1 ret_data.astype("float64", copy=False)
#       2 ret_data.index = pd.to_datetime(ret_data.index)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5881             # else, only a single dtype is given
#    5882             new_data = self._data.astype(
# -> 5883                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5884             )
#    5885             return self._constructor(new_data).__finalize__(self)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ...

# %%
ret_data = ret_data.sort_index()

# %%
ret_data.head()
# Out:
# CUSIP           95710 105510     282410     780010    1165910 2942910  \
# DATE
# 1970-01-02  -0.006897    NaN  -0.009804   0.013605   0.094118     NaN
# 1970-01-05  -0.017361    NaN   0.003300   0.033557   0.021505     NaN
# 1970-01-06  -0.010601    NaN  -0.006579  -0.012987  -0.010526     NaN
# 1970-01-07  -0.021429    NaN  -0.009934  -0.006579  -0.021277     NaN
# 1970-01-08   0.010949    NaN   0.003344   0.000000   0.000000     NaN
#
# CUSIP        3439310    4273510    4333910 5377410  ... M8743P10 N4727910  \
# DATE                                                ...
# 1970-01-02  0.146341   0.013043   0.095238     NaN  ...      NaN      NaN
# 1970-01-05  0.021277  -0.004292   0.054348     NaN  ...      NaN      NaN
# 1970-01-06  0.000000  -0.025862  -0.025773     NaN  ...      NaN      NaN
# 1970-01-07  0.000000   0.004425  -0.010582     NaN  ...      NaN      NaN
# 1970-01-08  0.041667   0.008811   0.080214     NaN  ...      NaN      NaN
#
# ...

# %%
ret_data.astype("float64", copy=False).head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-2183ede4c82c> in <module>
# ----> 1 ret_data.astype("float64", copy=False).head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5881             # else, only a single dtype is given
#    5882             new_data = self._data.astype(
# -> 5883                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5884             )
#    5885             return self._constructor(new_data).__finalize__(self)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ...

# %%
ret_data.dtypes
# Out:
# CUSIP
# 95710       object
# 105510      object
# 282410      object
# 780010      object
# 1165910     object
#              ...
# V8726M10    object
# Y0553W10    object
# Y2573F10    object
# Y7169G10    object
# Y9530810    object
# Length: 3764, dtype: object

# %%
ret_data = pd.read_pickle('data/ret_data.pkl')

# %%
ret_data.iloc[0]
# Out:
# CUSIP
# 95710       -0.006897
# 105510            NaN
# 282410      -0.009804
# 780010       0.013605
# 1165910      0.094118
#               ...
# V8726M10          NaN
# Y0553W10          NaN
# Y2573F10          NaN
# Y7169G10          NaN
# Y9530810          NaN
# Name: 1970-01-02 00:00:00, Length: 3764, dtype: object

# %%
index_data = pd.read_sas("data/dsi.sas7bdat")
index_data.index = pd.to_datetime(index_data["date"])

# %%
index_data.head()
# Out:
#                  date    VWRETD    VWRETX    EWRETD    EWRETX      TOTVAL  \
# date
# 1925-12-31 1925-12-31       NaN       NaN       NaN       NaN  27487487.2
# 1926-01-02 1926-01-02  0.005689  0.005689  0.009516  0.009516  27600296.6
# 1926-01-04 1926-01-04  0.000706  0.000706  0.005780  0.005780  27577892.1
# 1926-01-05 1926-01-05 -0.004821 -0.004867 -0.001927 -0.002030  27530212.5
# 1926-01-06 1926-01-06 -0.000423 -0.000427  0.001182  0.001155  27618772.6
#
#             TOTCNT      USDVAL  USDCNT  SPRTRN  SPINDX
# date
# 1925-12-31   503.0         NaN     NaN     NaN     NaN
# 1926-01-02   497.0  27366755.7   494.0     NaN     NaN
# 1926-01-04   502.0  27479721.6   495.0     NaN     NaN
# 1926-01-05   501.0  27561757.1   499.0     NaN     NaN
# 1926-01-06   505.0  27526837.5   500.0     NaN     NaN

# %%
records = pd.read_csv("data/records.csv")
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
from datetime import datetime, timedelta

# %%
date_format = "%m/%d/%Y"
a = datetime.strptime('8/18/2008', date_format)
b = datetime.strptime('9/26/2008', date_format)
a - timedelta(12)
# Out:
# datetime.datetime(2008, 8, 6, 0, 0)

# %%
index_data[a : b].iloc[-1]
# Out:
# date      2008-09-26 00:00:00
# VWRETD            -0.00198477
# VWRETX             -0.0022433
# EWRETD            -0.00825126
# EWRETX            -0.00858331
# TOTVAL             1.6648e+10
# TOTCNT                   6888
# USDVAL            1.66857e+10
# USDCNT                   6887
# SPRTRN             0.00316744
# SPINDX                1213.01
# Name: 2008-09-26 00:00:00, dtype: object

# %%
np.linalg.lstsq(np.array([[1, 2, 3], [1, 1, 1]]).T, [2, 3, 5])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   """Entry point for launching an IPython kernel.
# (array([1.5       , 0.33333333]),
#  array([0.16666667]),
#  2,
#  array([4.07914333, 0.60049122]))

# %%
list(zip([1, 2], [3, 4]))
# Out:
# [(1, 3), (2, 4)]

# %%
def cal_car(date, cusip):
    date_format = "%Y-%m-%d"
    date = datetime.strptime(date, date_format)
    begin, end = date - timedelta(345),  date - timedelta(96)
    result = {0: np.nan, 1:np.nan, 3:np.nan, 5: np.nan}
    keys = ["car_w0", "car_w1", "car_w3", "car_w5"]
    if cusip in ret_data.columns:
        return {k: v for k, v in zip(keys, list(result.values()))}        

    ret = ret_data[cusip][begin: end].astype('float64')

    mkt = index_data.loc[begin: end, "VWRETX"]

    beta = ret.cov(mkt)
    alpha = ret.mean() - mkt.mean() * beta

    
    for w in result:
        try:
            wbegin, wend = date - timedelta(w), date + timedelta(w)
            result[w] = (ret_data.loc[wbegin: wend, cusip].astype('float64') - beta * index_data.loc[wbegin: wend, "VWRETX"] - alpha).sum()
        except:
            pass

    return {k: v for k, v in zip(keys, list(result.values()))}

# %%
cal_car("1995-02-01", 12650110)
# Out:
# {'car_w0': -0.0018264973575012452,
#  'car_w1': 0.024093469907702884,
#  'car_w3': 0.024365442224538007,
#  'car_w5': -0.03897160000790016}

# %%
pd.DataFrame([{"a":1, "b":2},{"a":2, "b":3}])
# Out:
#    a  b
# 0  1  2
# 1  2  3

# %%
for _ ,row in records.head().iterrows():
    print(row)
# Out:
# CIK           77098
# date     1995-03-03
# CUSIP      02909210
# Name: 0, dtype: object
# CIK          785161
# date     1995-02-01
# CUSIP      42192410
# Name: 1, dtype: object
# CIK           31791
# date     1995-02-09
# CUSIP      26845710
# Name: 2, dtype: object
# CIK           30819
# date     1995-03-30
# CUSIP      12650110
# Name: 3, dtype: object
# CIK           30697
# date     1995-01-18
# CUSIP      89592710
# Name: 4, dtype: object
