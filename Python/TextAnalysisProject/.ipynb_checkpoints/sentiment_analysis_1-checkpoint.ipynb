# %%
import sys
sys.path.append("./lib64/python3.6/site-packages")

# %%
import pandas as pd
import numpy as np
import os
import re

# %%
dct = pd.read_csv('data/LoughranMcDonald_MasterDictionary_2018.csv')

# %%
dct.columns
# Out:
# Index(['Word', 'Sequence Number', 'Word Count', 'Word Proportion',
#        'Average Proportion', 'Std Dev', 'Doc Count', 'Negative', 'Positive',
#        'Uncertainty', 'Litigious', 'Constraining', 'Superfluous',
#        'Interesting', 'Modal', 'Irr_Verb', 'Harvard_IV', 'Syllables',
#        'Source'],
#       dtype='object')

# %%
dct['Negative'].unique()
# Out:
# array([   0, 2009, 2011, 2014, 2012])

# %%
dct['Positive'].unique()
# Out:
# array([   0, 2009, 2012, 2011])

# %%
negative = dct.loc[dct['Negative'] > 0 ,'Word']
positive = dct.loc[dct['Positive'] > 0 ,'Word']

# %%
positive = set(s.lower() for s in positive)
negative = set(s.lower() for s in negative)

# %%
"a|b.c".split()
# Out:
# ['a|b.c']

# %%
prog_txt = re.compile('<TEXT>([.\\\\]*)</TEXT>')
prog_wd = re.compile('[a-zA-Z]+')

# %%
prog_txt.findall(test)
# Out:
# []

# %%
prog_line = re.compile('\n')
prog_nbsp = re.compile('&nbsp;')
prog_tag = re.compile('<.*?>')

# %%
prog_wd.findall("A is Ok")
# Out:
# ['A', 'is', 'Ok']

# %%
res = []
for root, _, files in os.walk("data/"):
    for file in files:
        CIK, date = file.split('|')[0], file.split('|')[1].split('.')[0]
        d = {'CIK': int(CIK), 'date': date}
        with open(root + '/' + file, 'r') as file:
            text = file.read()
            text = text[text.find('<DOCUMENT>'): text.find('</DOCUMENT>')]

            text = prog_line.sub(' ', text)
            text = prog_nbsp.sub(' ', text)
            text = prog_tag.sub('', text)
            
            words = prog_wd.findall(text)
            words = [w.lower() for w in words]
            
            diff = 0
            for w in words:
                if w in positive:
                    diff += 1
                elif w in negative:
                    diff -= 1
            
            try:
                d['pos_neg'] = diff / len(words)
            except:
                d['pos_neg'] = np.nan
            res.append(d)
            
res_df = pd.DataFrame(res)

# %%
res_df[res_df['pos_neg'] > 0]
# Out:
#           CIK        date   pos_neg
# 0     1405041  2012-12-05  0.002083
# 1     1025536  2012-11-30  0.002770
# 2     1415684  2012-11-28  0.003736
# 3     1512931  2012-11-13  0.002299
# 4     1005276  2012-10-02  0.010622
# ...       ...         ...       ...
# 9544   896429  2011-06-01  0.005535
# 9546  1322439  2011-04-29  0.004329
# 9547  1000180  2011-04-21  0.003802
# 9548  1345840  2011-05-05  0.002890
# 9550   866970  2011-04-28  0.000985
#
# [3646 rows x 3 columns]
